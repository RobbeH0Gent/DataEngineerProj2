# %%
import pandas as pd


df1 = pd.read_csv('C:/Users/Eli/Desktop/DATA/Activiteit_vereist_contact.csv')
df2 = pd.read_csv('C:/Users/Eli/Desktop/DATA/Activiteitscode.csv')
df3 = pd.read_csv('C:/Users/Eli/Desktop/DATA/Contact.csv')

# %%
filtered_contacts = df1[~df1['crm_ActiviteitVereistContact_ActivityId'].isin(df2['crm_ActiviteitsCode_Activiteitscode'])]
filtered_contacts2 = df1[~df1['crm_ActiviteitVereistContact_ReqAttendee'].isin(df3['crm_Contact_Persoon_ID'])]
# Out:
#             crm_FinancieleData_OndernemingID  crm_FinancieleData_Boekjaar  \
# 2115    02E2C17D-A213-E211-9DAA-005056B06EB4                         2010
# 65945   5C161136-A768-E111-B43A-00505680000A                         2009
# 97912   8AC9D862-9668-E111-B43A-00505680000A                         2003
# 157087  DFAAE601-1969-E111-B43A-00505680000A                         2007
#
#         crm_FinancieleData_Aantal_maanden  \
# 2115                                 12.0
# 65945                                 NaN
# 97912                                 NaN
# 157087                                NaN
#
#        crm_FinancieleData_Toegevoegde_waarde crm_FinancieleData_FTE  \
# 2115                                     NaN                      0
# 65945                                    NaN                      0
# 97912                                    NaN                   92,7
# 157087                                   NaN                    4,3
#
# ...

# %%
df2
# Out:
#                          crm_Account_Account  \
# 0       00002561-6762-EC11-8F8F-000D3A2E7738
# 1       00002DAC-0A69-E111-B43A-00505680000A
# 2       00002F96-DC68-E111-B43A-00505680000A
# 3       00005967-2959-E411-8F25-005056B06EB4
# 4       00006DCD-DF68-E111-B43A-00505680000A
# ...                                      ...
# 289049  FFFF2E96-DC68-E111-B43A-00505680000A
# 289050  FFFF6CCD-DF68-E111-B43A-00505680000A
# 289051  FFFF8A20-801E-E211-9A2B-005056B06EC4
# 289052  FFFF8DBC-B567-E111-A00F-00505680000A
# 289053  FFFFAF46-AD68-E111-B43A-00505680000A
#
#        crm_Account_Adres_Geografische_regio  \
# 0                           Mechelen-Kempen
# 1                           Oost-Vlaanderen
# 2                                   Limburg
# 3                            Vlaams-Brabant
# 4                           West-Vlaanderen
# ...                                     ...
# 289049                       Vlaams-Brabant
# 289050                  Brusselse metropool
# ...

# %%
df3
# Out:
#                                   Persoon_ID  Persoonnr Status_Persoon  \
# 0       000025F6-EF15-EE11-8F6D-6045BD895420     596398         Actief
# 1       00004BCD-BD69-E111-B43A-00505680000A     320520       Inactief
# 2       00005D29-3224-E311-8A47-005056B06EC4     378241       Inactief
# 3       00006033-9469-E111-B43A-00505680000A     343308         Actief
# 4       0000628D-6169-E111-B43A-00505680000A     325745         Actief
# ...                                      ...        ...            ...
# 580976  FFFFB3B0-EF58-E311-BBFD-005056B06EB4     382711         Actief
# 580977  FFFFD240-FF67-E111-A00F-00505680000A     125137       Inactief
# 580978  FFFFD3E4-0768-E111-A00F-00505680000A     145456         Actief
# 580979  FFFFD74F-F067-E111-A00F-00505680000A      96987       Inactief
# 580980  FFFFF956-2D7C-EB11-811A-001DD8B72B61     527520         Actief
#
#        Marketing_Communicatie
# 0                      Strikt
# 1                    Flexibel
# ...
